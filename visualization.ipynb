# %%
# %load_ext autoreload
# %autoreload 2

# %%
import src.examplescript as ex
import os

# %%
#Set project_path

# %%
#print("working directory", os.getcwd())
project_path = os.getcwd()
ice_conc, iceyear, icelat, icelon = ex.icecore_info(project_path)
print("path", type(ice_conc), type(iceyear))
# Out:
# path <class 'numpy.ndarray'> <class 'pandas.core.series.Series'>
# Model concat <xarray.DataArray (year: 165)>
# array([ 2.5812724,  3.0981681,  2.9765775,  2.1775584,  3.764395 ,
#         3.3724217,  3.0657196,  2.9411068,  2.8821366,  3.508379 ,
#         2.6924398,  2.3894262,  4.266213 ,  2.9829385,  3.0662432,
#         3.3723822,  3.0992754,  3.1414213,  3.844466 ,  2.9879553,
#         3.3274326,  2.9278955,  3.6872792,  3.397073 ,  3.3580341,
#         3.297504 ,  3.5119505,  4.634672 ,  4.2560363,  3.495691 ,
#         3.1925466,  2.7530751,  3.888524 ,  3.4583383,  3.2850318,
#         3.4842455,  4.1232357,  5.0811386,  4.1263905,  4.7255864,
#         4.350721 ,  5.271402 ,  3.933779 ,  5.337951 ,  4.751893 ,
#         4.538965 ,  5.2234316,  4.728253 ,  5.4890656,  5.376468 ,
#         5.2722054,  6.654763 ,  6.0749464,  6.2204385,  5.6209874,
#         8.322508 ,  7.503231 ,  7.941205 ,  5.9784646,  7.0239797,
# ...

# %%
model_conc = ex.make_concentration(project_path, icelat, icelon)
print("Model concat", model_conc)
print("ice_conc", ice_conc)
# Out:
# Model concat <xarray.DataArray (year: 165)>
# array([ 2.5812724,  3.0981681,  2.9765775,  2.1775584,  3.764395 ,
#         3.3724217,  3.0657196,  2.9411068,  2.8821366,  3.508379 ,
#         2.6924398,  2.3894262,  4.266213 ,  2.9829385,  3.0662432,
#         3.3723822,  3.0992754,  3.1414213,  3.844466 ,  2.9879553,
#         3.3274326,  2.9278955,  3.6872792,  3.397073 ,  3.3580341,
#         3.297504 ,  3.5119505,  4.634672 ,  4.2560363,  3.495691 ,
#         3.1925466,  2.7530751,  3.888524 ,  3.4583383,  3.2850318,
#         3.4842455,  4.1232357,  5.0811386,  4.1263905,  4.7255864,
#         4.350721 ,  5.271402 ,  3.933779 ,  5.337951 ,  4.751893 ,
#         4.538965 ,  5.2234316,  4.728253 ,  5.4890656,  5.376468 ,
#         5.2722054,  6.654763 ,  6.0749464,  6.2204385,  5.6209874,
#         8.322508 ,  7.503231 ,  7.941205 ,  5.9784646,  7.0239797,
#         7.9078336,  6.7952075,  7.7574553,  7.9919095,  9.117665 ,
# ...
